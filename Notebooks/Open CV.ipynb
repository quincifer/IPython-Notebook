# %%
from myro import*
import cv2
import numpy
from PIL import*
import matplotlib.pyplot as plt
# %matplotlib inline

# we'll use urllib for get images
import urllib
def url_to_array(url):
    request = urllib.urlopen(url)
    arr = np.asarray(bytearray(request.read()), dtype=np.uint8)
    return arr
# Out:
# WARNING: xmpp was not found: chat and webservices will not be available
# (c) 2006-2007 Institute for Personal Robots in Education
# [See http://www.roboteducation.org/ for more information]
# Myro version 2.9.1 is ready!

# %%
from PIL import Image

# %%
#cv2.imread takes a picture path parameter and an interger(flag). -1=loads image as such including alpha, 0=Grayscale, 1=Color
pic = cv2.imread(r"hello.jpg",1)
#turn the picture to an array
arr = numpy.array(pic) #NOT NEEDED
# cv2.imdecode: load an image from a NumPy array
#img = cv2.imdecode(np.frombuffer(arr, np.uint8), 1)
#pic_img = cv2.imdecode(arr, 1)

# %%
picture=makePicture("/Users/Darren/Documents/KeithTutorial/IPython-Notebook/Quincy-is-da-Bomb/coolclassroom.jpg")
picture2=makePicture("/Users/Darren/Documents/KeithTutorial/IPython-Notebook/Quincy-is-da-Bomb/coolteacher.jpg")
picture3=makePicture("/Users/Darren/Documents/KeithTutorial/IPython-Notebook/Quincy-is-da-Bomb/coolguy.jpg")
theCoolestClassInTheWorld=[picture,picture2,picture3]
# Out:
# Hey Quincy!
# Hey Quincy!
# Hey Quincy!
# /Users/Darren/anaconda/envs/jyro/lib/python2.7/site-packages/myro/graphics.py:1107: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.pixels == None:

# %%
arr = picture2.pixels

# %%
# cv2.resize: resize an image
# http://docs.opencv.org/modules/imgproc/doc/geometric_transformations.html?highlight=resize#cv2.resize
newPic = cv2.resize(arr,(arr.shape[1],arr.shape[0]*2))
plt.imshow(newPic)

# %%
#creates an array of PIL image
arr = numpy.array(newPic)
#prints size of array
arr.shape

# %%
im_cv = cv2.imread("output1.png")[:,:,:]
imshow(im_cv)
im_cv = im_cv[:, :, ::-1]
imshow(im_cv)

# %%
newPic = cv2.imread("/Users/Darren/Documents/KeithTutorial/IPython-Notebook/Quincy-is-da-Bomb/coolteacher.jpg",1)

# %%
print newPic
# Out:
# [[[ 36  28  28]
#   [ 35  27  27]
#   [ 31  25  26]
#   ...,
#   [111  88  80]
#   [103  79  73]
#   [ 97  69  68]]
#
#  [[ 45  35  35]
#   [ 42  34  34]
#   [ 40  32  32]
#   ...,
#   [119  98  90]
#   [115  91  85]
#   [110  83  79]]
#
#  [[ 56  44  42]
#   [ 55  43  41]
#   [ 54  42  40]
#   ...,
#   [108  87  79]
#   [106  82  76]
#   [103  76  72]]
#
#  ...,
#  [[ 13  11  11]
#   [ 13  11  11]
#   [ 13  11  11]
#   ...,
#   [  3   5   5]
#   [  4   6   6]
#   [  8   7   9]]
#
#  [[ 14  12  12]
#   [ 14  12  12]
#   [ 14  12  12]
#   ...,
#   [  6   8   8]
#   [  7   9   9]
#   [ 10   9  11]]
#
#  [[ 14  12  12]
#   [ 14  12  12]
#   [ 14  12  12]
#   ...,
#   [  6   8   8]
#   [  7   9   9]
#   [ 10   9  11]]]

# %%
# cv2.resize: resize an image
# http://docs.opencv.org/modules/imgproc/doc/geometric_transformations.html?highlight=resize#cv2.resize
newPic = cv2.resize(newPic,(newPic.shape[1],newPic.shape[0]*2))
plt.imshow(newPic)
